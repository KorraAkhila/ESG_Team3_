# %%
"""1"""
if True:
    print("Hello")
print("Welcome")
# Out:
# Hello
# Welcome

# %%
"""2"""
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
"""3
1age : should not start with integer
user-name : should not use hyphen
totalAmount : valid
class : is a keyword, we should not use keywords
_value : valid"""

# %%
"""4
emp-age : emp_age
2salary : salary2
for : is a keyword so we can add anything to make it not a keyword """

# %%
#5
x=10  #value of x is 10 
y=20  #value of y is 20 
print(x+y)  #sum of x and y is being printed in the output console
# Out:
# 30

# %%
#6
print("Hello") #printing Hello
print("How are you?") #printing How are you?
# Out:
# Hello
# How are you?

# %%
#7
a=7 #integer
b=0.55 #float
c= "Keerthana" #string
d=True #boolean
print(a,'is',type(a))
print(b,'is',type(b))
print(c,'is',type(c))
print(d,'is',type(d))
# Out:
# 7 is <class 'int'>
# 0.55 is <class 'float'>
# Keerthana is <class 'str'>
# True is <class 'bool'>

# %%
"""8
"50" : string
50 : integer
12.5 : float
False: Boolean"""
print(type("50"))
print(type(50))
print(type(12.5))
print(type(False))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#9
print(int("40"),type(int("40")))
print(float(25),type(float(25)))
print(str(9.5),type(str(9.5)))
# Out:
# 40 <class 'int'>
# 25.0 <class 'float'>
# 9.5 <class 'str'>

# %%
#10
user_input=int(input("Enter anything: "))
print(int(user_input))
print(float(user_input))
print(str(user_input))
# Out:
# 8
# 8.0
# 8

# %%
#11
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

add= num1 + num2
sub = num1 - num2
mul= num1 * num2
div = num1 / num2
fd = num1 // num2
mod = num1 % num2
exp= num1 ** num2

print("Addition:", add)
print("Subtraction:", sub)
print("Multiplication:", mul)
print("Division:", div)
print("Floor Division:", fd)
print("Modulus:", mod)
print("Exponentiation:", exp)
# Out:
# Addition: 13.0
# Subtraction: -1.0
# Multiplication: 42.0
# Division: 0.8571428571428571
# Floor Division: 0.0
# Modulus: 6.0
# Exponentiation: 279936.0

# %%
#12.
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Equal to:", num1 == num2)
print("Not equal to:", num1 != num2)
print("Greater than:", num1 > num2)
print("Less than:", num1 < num2)
print("Greater than or equal to:", num1 >= num2)
print("Less than or equal to:", num1 <= num2)
# Out:
# Equal to: False
# Not equal to: True
# Greater than: True
# Less than: False
# Greater than or equal to: True
# Less than or equal to: False

# %%
# 13.
num = int(input("Enter a number: "))

if num > 10 and num < 50:
    print("True")
else:
    print("False")

if num <= 10 or num >= 50:
    print("False")
else:
    print("True")

if not (num > 10 and num < 50):
    print("False")
else:
    print("True")
# Out:
# True
# True
# True
